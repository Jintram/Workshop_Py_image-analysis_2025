# %%
import matplotlib.pyplot as plt
import skimage as ski

# Load example image
image = ski.data.page()

# Save example image to desktop
ski.io.imsave('/Users/m.wehrens/Desktop/page_original.tif', image)
